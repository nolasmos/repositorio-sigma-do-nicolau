# %% [markdown]
# <a href="https://colab.research.google.com/github/nolasmos/repositorio-sigma-do-nicolau/blob/main/pa27_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#jogo menu inteligente
#crie um sistema até o usuario sair
#menu
#par ou impar
#positivo/negativo
#maior
#sair

import random

while True:
    # Exibição do Menu
    print("\n" + "="*30)
    print("      JOGO MENU INTELIGENTE      ")
    print("="*30)
    print("[ 1 ] Jogar Par ou Ímpar")
    print("[ 2 ] Verificar Positivo ou Negativo")
    print("[ 3 ] Descobrir o Maior Número")
    print("[ 4 ] Sair do Jogo")
    print("="*30)

    opcao = input("Escolha uma opção (1-4): ").strip()
    print("-" * 30)

    # Opção 1: Par ou Ímpar (Jogo contra o computador)
    if opcao == "1":
        print("--- JOGO DO PAR OU ÍMPAR ---")
        escolha_usuario = input("Você quer Par [P] ou Ímpar [I]? ").strip().upper()

        if escolha_usuario not in ['P', 'I']:
            print(" Escolha inválida! Digite 'P' para Par ou 'I' para Ímpar.")
            continue

        num_usuario = int(input("Digite o seu número: "))
        num_computador = random.randint(0, 10)
        soma = num_usuario + num_computador
        resultado = "P" if soma % 2 == 0 else "I"

        print(f"-> Você jogou {num_usuario} e o computador jogou {num_computador}. Total: {soma}")
        print(f"-> Deu " + ("PAR!" if resultado == "P" else "ÍMPAR!"))

        if escolha_usuario == resultado:
            print(" Você VENCEU!")
        else:
            print(" O computador venceu!")

    # Opção 2: Positivo ou Negativo
    elif opcao == "2":
        print("--- POSITIVO OU NEGATIVO ---")
        num = float(input("Digite um número: "))
        if num > 0:
            print(f" O número {num} é POSITIVO.")
        elif num < 0:
            print(f" O número {num} é NEGATIVO.")
        else:
            print(" O número é ZERO (neutro).")

    # Opção 3: Maior Número
    elif opcao == "3":
        print("--- DESCOBRIR O MAIOR ---")
        n1 = float(input("Digite o primeiro número: "))
        n2 = float(input("Digite o segundo número: "))

        if n1 > n2:
            print(f" O primeiro número ({n1}) é MAIOR que o segundo ({n2}).")
        elif n2 > n1:
            print(f" O segundo número ({n2}) é MAIOR que o primeiro ({n1}).")
        else:
            print(" Ambos os números são iguais.")

    # Opção 4: Sair
    elif opcao == "4":
        print("Saindo do sistema... Obrigado por jogar! ")
        break

    # Validação para opções incorretas no menu
    else:
        print(" Opção inválida! Por favor, escolha um número de 1 a 4.")
# Out:
# ==============================
#       JOGO MENU INTELIGENTE
# ==============================
# [ 1 ] Jogar Par ou Ímpar
# [ 2 ] Verificar Positivo ou Negativo
# [ 3 ] Descobrir o Maior Número
# [ 4 ] Sair do Jogo
# ==============================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2527/4233806154.py in <cell line: 0>()
#      22     print("="*30)
#      23
# ---> 24     opcao = input("Escolha uma opção (1-4): ").strip()
#      25     print("-" * 30)
#      26
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#urna eletronica
#crir um programa de votaçao com 3 candidatos
#o sistema deve repetir até encerrar a votaçao
#contar votos, brancos e nulos
#ao encerrar, mostrar:
#total de votos, brancos e nulos e o vencedor
#mostrar se sitver empate e se nao houver votos validos mostrar:nenhum candidato recebeu votos
candidato_1 = 0
candidato_2 = 0
candidato_3 = 0
brancos = 0
nulos = 0
total_votos = 0

print("="*40)
print("     SISTEMA DE URNA ELETRÔNICA      ")
print("="*40)

while True:
    print("\nOPÇÕES DE VOTO:")
    print("[ 1 ] Candidato 1")
    print("[ 2 ] Candidato 2")
    print("[ 3 ] Candidato 3")
    print("[ 4 ] Voto em Branco")
    print("[ 5 ] Voto Nulo")
    print("[ 0 ] Encerrar Votação (Apenas Mesário)")
    print("-" * 40)

    voto = input("Digite o número correspondente ao seu voto: ").strip()

    if voto == "1":
        candidato_1 += 1
        total_votos += 1
        print("Voto para Candidato 1 confirmado! ")
    elif voto == "2":
        candidato_2 += 1
        total_votos += 1
        print("Voto para Candidato 2 confirmado! ")
    elif voto == "3":
        candidato_3 += 1
        total_votos += 1
        print("Voto para Candidato 3 confirmado! ")
    elif voto == "4":
        brancos += 1
        total_votos += 1
        print("Voto em BRANCO confirmado! ")
    elif voto == "5":
        nulos += 1
        total_votos += 1
        print("Voto NULO confirmado! ")
    elif voto == "0":

        confirmar = input("Tem certeza que deseja encerrar a votação? [S/N]: ").strip().upper()
        if confirmar == "S":
            print("\nVotação encerrada com sucesso! Processando resultados...")
            break
    else:
        print(" Opção inválida! Digite um número de 1 a 5, ou 0 para encerrar.")

print("\n" + "="*40)
print("           RESULTADO FINAL           ")
print("="*40)
print(f"Total de votos computados: {total_votos}")
print(f"• Votos Brancos: {brancos}")
print(f"• Votos Nulos: {nulos}")
print("-" * 40)
print(f"• Candidato 1: {candidato_1} voto(s)")
print(f"• Candidato 2: {candidato_2} voto(s)")
print(f"• Candidato 3: {candidato_3} voto(s)")
print("-" * 40)
votos_validos = candidato_1 + candidato_2 + candidato_3
if votos_validos == 0:
    print(" Nenhum candidato recebeu votos válidos.")
else:
    maior_voto = max(candidato_1, candidato_2, candidato_3)
    vencedores = []
    if candidato_1 == maior_voto:
        vencedores.append("Candidato 1")
    if candidato_2 == maior_voto:
        vencedores.append("Candidato 2")
    if candidato_3 == maior_voto:
        vencedores.append("Candidato 3")

    if len(vencedores) > 1:
        print(f" Houve um empate entre os candidatos: {', '.join(vencedores)}!")
    else:
        print(f" O vencedor da eleição é: {vencedores[0]}!")

print("="*40)
# Out:
# ========================================
#      SISTEMA DE URNA ELETRÔNICA
# ========================================
#
# OPÇÕES DE VOTO:
# [ 1 ] Candidato 1
# [ 2 ] Candidato 2
# [ 3 ] Candidato 3
# [ 4 ] Voto em Branco
# [ 5 ] Voto Nulo
# [ 0 ] Encerrar Votação (Apenas Mesário)
# ----------------------------------------
# Digite o número correspondente ao seu voto: 3
# Voto para Candidato 3 confirmado!
#
# OPÇÕES DE VOTO:
# [ 1 ] Candidato 1
# [ 2 ] Candidato 2
# [ 3 ] Candidato 3
# [ 4 ] Voto em Branco
# [ 5 ] Voto Nulo
# [ 0 ] Encerrar Votação (Apenas Mesário)
# ----------------------------------------
# Digite o número correspondente ao seu voto: 3
# Voto para Candidato 3 confirmado!
#
# OPÇÕES DE VOTO:
# [ 1 ] Candidato 1
# [ 2 ] Candidato 2
# [ 3 ] Candidato 3
# [ 4 ] Voto em Branco
# [ 5 ] Voto Nulo
# [ 0 ] Encerrar Votação (Apenas Mesário)
# ----------------------------------------
# Digite o número correspondente ao seu voto: 2
# Voto para Candidato 2 confirmado!
#
# OPÇÕES DE VOTO:
# [ 1 ] Candidato 1
# [ 2 ] Candidato 2
# [ 3 ] Candidato 3
# [ 4 ] Voto em Branco
# [ 5 ] Voto Nulo
# [ 0 ] Encerrar Votação (Apenas Mesário)
# ----------------------------------------
# Digite o número correspondente ao seu voto: 1
# Voto para Candidato 1 confirmado!
#
# OPÇÕES DE VOTO:
# [ 1 ] Candidato 1
# [ 2 ] Candidato 2
# [ 3 ] Candidato 3
# [ 4 ] Voto em Branco
# [ 5 ] Voto Nulo
# [ 0 ] Encerrar Votação (Apenas Mesário)
# ----------------------------------------
# Digite o número correspondente ao seu voto: 1
# Voto para Candidato 1 confirmado!
#
# OPÇÕES DE VOTO:
# [ 1 ] Candidato 1
# [ 2 ] Candidato 2
# [ 3 ] Candidato 3
# [ 4 ] Voto em Branco
# [ 5 ] Voto Nulo
# [ 0 ] Encerrar Votação (Apenas Mesário)
# ----------------------------------------
# Digite o número correspondente ao seu voto: 0
# Tem certeza que deseja encerrar a votação? [S/N]: S
#
# Votação encerrada com sucesso! Processando resultados...
#
# ========================================
#            RESULTADO FINAL
# ========================================
# Total de votos computados: 5
# • Votos Brancos: 0
# • Votos Nulos: 0
# ----------------------------------------
# • Candidato 1: 2 voto(s)
# • Candidato 2: 1 voto(s)
# • Candidato 3: 2 voto(s)
# ----------------------------------------
#  Houve um empate entre os candidatos: Candidato 1, Candidato 3!
# ========================================
