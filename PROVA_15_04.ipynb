# %% [markdown]
# <a href="https://colab.research.google.com/github/nolasmos/repositorio-sigma-do-nicolau/blob/main/PROVA_15_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# prova skibidi do nicolas nascimento do 1E

# %%
numero = int(input("digite um numero: "))

if numero % 2 == 0:
    print(f"o numero {numero} é par")
else:
    print(f"o numero {numero} é impar")
# Out:
# digite um numero: 5
# o numero 5 é impar

# %%
n1 = int(input("digite um numero: "))
n2 = int(input("digite outro numero: "))

if n1 > n2:
  print(f"o numero {n1} é maior que o numero {n2}")
if n1 < n2:
  print(f"o numero {n1} é menor que o numero {n2}")
if n1 == n2:
  print(f"o numero {n1} é igual ao numero {n2}")
# Out:
# digite um numero: 10
# digite outro numero: 9
# o numero 10 é maior que o numero 9

# %%
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
n4 = float(input("Digite a quarta nota: "))

media = (n1 + n2 + n3 + n4) / 4

if media >= 7:
  print (f'foi aprovado com a media de {media}')
elif media >= 5 and media < 7:
  print(f"você ficou de recuperação com a media de {media}")
else:
  print(f'você foi reprovado com a media de {media}')
# Out:
# Digite a primeira nota: 4
# Digite a segunda nota: 4
# Digite a terceira nota: 4
# Digite a quarta nota: 4
# você foi reprovado com a media de 4.0

# %%
idade = int(input("digite sua idade: "))

if idade <=12:
  print("você é uma criança")
if idade <=17 and idade > 12:
  print("você é um adolescente")
if idade >=18 and idade <=59:
  print("você é um adulto")
if idade > 59:
  print("você é um idoso")
# Out:
# digite sua idade: 60
# você é um idoso

# %%
s1 = int(input("crie a sua senha"))
s2 = int(input("digite a sua senha"))

if s1 == s2:
  print("acesso permitido")
else:
  print("acesso negado")
# Out:
# crie a sua senha676767
# digite a sua senha606060
# acesso negado

# %%
n1 = int(input("digite um numero: "))

if n1 > 0:
  print(f"o numero {n1} é positivo")
if n1 < 0:
  print("o numero é negativo")
if n1 == 0:
  print("o numero é zero")
# Out:
# digite um numero: -1
# o numero é negativo

# %%
print("soma =1")
print("subtracao =2")
print("multiplicacao =3")
print("divisao =4")
a = int(input("digite um numero: "))
b = int(input("digite outro numero: "))
c = int(input("escolha a operaçao: "))

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
if c == 1:
 print("-----------------------------soma-------------------------------")
 print(f"a soma de {a} e {b} é igual à: {soma}")
 print("-----------------------------------------------------------------")
if c == 2:
 print("-------------------subtracao-------------------------------------")
 print(f"a subtraçao de {a} e {b} é igual à: {subtracao}")
 print("-----------------------------------------------------------------")
if c == 3:
 print("-------------------multiplicacao---------------------------------")
 print(f"a multiplicacao de {a} e {b} é igual à: {multiplicacao}")
 print("-----------------------------------------------------------------")
if c == 4:
 print("-------------------divisao---------------------------------------")
 print(f"a divisao de {a} e {b} é igual à: {divisao}")
 print("-----------------------------------------------------------------")
# Out:
# soma =1
# subtracao =2
# multiplicacao =3
# divisao =4
# digite um numero: 4
# digite outro numero: 4
# escolha a operaçao: 4
# -------------------divisao---------------------------------------
# a divisao de 4 e 4 é igual à: 1.0
# -----------------------------------------------------------------

# %%
dia = int(input("digite o dia da semana = "))
if dia == 1:
  print("hoje é domingo")
if dia == 2:
 print("hoje é segunda")
if dia == 3:
  print("hoje é terça")
if dia == 4:
  print("hoje é quarta")
if dia == 5:
  print("hoje é quinta")
if dia == 6:
  print("hoje é sexta")
if dia == 7:
  print("hoje é sabado")
# Out:
# digite o dia da semana = 1
# hoje é domingo

# %%
ano = int(input("digite o ano: "))

if ano % 4 == 0:
  print(f"o ano {ano} é bissexto")
else:
  print(f"o ano {ano} não é bissexto")
# Out:
# digite o ano: 2024
# o ano 2024 é bissexto

# %%
v1 = int(input("digite o valor do produto: "))
if v1 >= 100:
 v2 = v1 / 10
 valor = v1 - v2
 print(f"o seu valor ficou {valor}")
if v1 >= 50 and v1 < 100:
  v2 = v1 / 5
  valor = v1 - v2
  print(f"o seu valor ficou {valor}")
# Out:
# digite o valor do produto: 50
# o seu valor ficou 40.0
