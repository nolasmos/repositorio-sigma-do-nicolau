# %% [markdown]
# <a href="https://colab.research.google.com/github/nolasmos/repositorio-sigma-do-nicolau/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hello world')
# Out:
# hello world

# %%
print('skibidi toilet sigma 67')
# Out:
# skibidi toilet sigma 67

# %%
print('nicolau é um bunitao')
# Out:
# nicolau é um bunitao

# %% [markdown]
# aula de programação/algoritmos
# * cálculo
#
# #entrada
# * ler lado1
# * ler lado2
#
# #processamento
# area = lado1 * lado2
#
# #saída
# imprimir area

# %%
from re import X
#codigo mucho bueno do nicolebas para calcular area

#entrada
lado1 = 5
lado2 = 4
lado1 * lado2
# Out:
# 20

# %%
#processamento da conta super fantastica do nicolebasa
area = lado1 * lado2

# %%
# saida da conta super fantastica do nicolebas
print (f"total da área = {area}")
if (area) > 19:
  print ("achei facil")
# Out:
# total da área = 20
# achei facil

# %%
#tipos numericos

idade=25 #int

altura = 1.75 #float

numero_complexo = 2 + 3j #complex

#tipos texto

nome = "alice" #str

#tipo boleano
esta_chovendo =False #bool
