# %% [markdown]
# <a href="https://colab.research.google.com/github/nolasmos/repositorio-sigma-do-nicolau/blob/main/pa18_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#compilador:traduz o codigo de uma vez para o codigo da maquina(gx:c/c=++)
#interpretador:le e  executa o codigo linha por linha sem um executavel separado(python e etc)
#SDk:conjunto de ferramentas, bibliotecas e documentaçao para desenvolver uma plataforma
#ide:ambiente completa com editor, terminal e recursos
#bibliote ca: conjunto de funçoes prontas q vc chama no seu codigo
#framework: estrutura maior que define o "esqueleto" da aplicaçao e chama seu codigo
#parametro:o valor q recebe a funcao para trabalhar
#retorno: o valor q o algaritmo devolve

# %%
#exercicios
nome = (input(f"coloque seu nome: "))
idade = int(input(f"coloque sua idade: "))
altura = float(input(f"coloque sua altura: "))
cidade = (input(f"fale o nome de sua cidade: "))
nota = float(input(f"coloque sua nota: "))
print (f"voce é o {nome}, tem {idade} anos, tem {altura} de altura, e mora em {cidade}, voce tirou {nota}")
# Out:
# coloque seu nome: nicolau
# coloque sua idade: 15
# coloque sua altura: 1.75
# fale o nome de sua cidade: maua city
# coloque sua nota: 100
# voce é o nicolau, tem 15 anos, tem 1.75 de altura, e mora em maua city, voce tirou 100.0

# %%
nota1 = float(input("coloque a primeira nota: "))
nota2 = float(input("coloque a segunda nota: "))
nota3 = float(input("coloque a terceira nota: "))
nota4 = float(input("coloque a quarta nota: "))

media = (nota1 + nota2 + nota3 + nota4) / 4
print(f"sua media é de: {media}")
# Out:
# coloque a primeira nota: 2
# coloque a segunda nota: 2
# coloque a terceira nota: 2
# coloque a quarta nota: 2
# 2.0

# %%
#a) Transforme texto1 em inteiro e some com 10 b) Transforme texto2 em real e
#multiplique por 2 c) Transforme número em texto e junte com a palavra "anos"
n1 = int(input("digite um numero ")) + 10
n2 = float(input("digite um numero ")) * 2
n3 = (input("digite um numero"))
print(f"{n1}")
print(f"{n2}")
print(f"{n3} anos")
# Out:
# digite um numero 1
# digite um numero 1
# digite um numero1
# 11
# 2.0
# 1 anos

# %% [markdown]
# Exercício 4 – Expressões aritméticas
# Calcule e mostre o resultado de:
# • O dobro de 15
# • A metade de 90
# • O resto da divisão de 17 por 5
# • 2 elevados à potência 4
# • A média de 10, 8 e 6

# %%
n1 = 15 * 2
n2 = 90 / 2
n3 = 17 / 5
n4 = 2 * 2 * 2 * 2
n5 = (10 + 8 + 6) / 3
print(f"15 vezes 2 = {n1}")
print(f"90 dividido por 2 ={n2}")
print(f"17 dividido por 5 ={n3}")
print(f"2 elevada a quarta potencia ={n4}")
print(f"media de 10,8,6 ={n5}")
# Out:
# 15 vezes 2 = 30
# 90 dividido por 2 =45.0
# 17 dividido por 5 =3.4
# 2 elevada a quarta potencia =16
# media de 10,8,6 =8.0

# %% [markdown]
# Exercício 5 – Comparações (relacionais)
# Mostre o resultado (True ou False) das comparações:
# Python
# idade = 16
# nota = 8.5
# preco = 45.0

# %%
idade = int(input("digite sua idade: "))
nota = float(input("digite s,  ua nota: "))
preco = float(input("digite o preco: "))

if idade > 17:
  print("voce é maior de idade")
else:
  print("voce é menor de idade")
if nota > 5:
  print("voce passou")
else:
  print("voce reprovou")
if preco < 50:
  print("ta barato")
else:
  print("ta caro")
# Out:
# digite sua idade: 10
# digite sua nota: 10
# digite o preco: 10
# voce é menor de idade
# voce passou
# ta barato

# %% [markdown]
# Exercício 6 – Situação prática
# Um produto custa R$ 80,00. O cliente ganhou 10% de desconto.
# Faça um programa que calcule e mostre:
# • O valor do desconto
# • O valor final a pagar
# • Se o valor final é menor que 75.00 (True ou False)

# %%
produto = 80
desconto = 0.90
preco = produto * desconto
if preco < 75:
  print(f"{preco} menor que 75")
else:
  print(f"{preco} e maior que 75")
# Out:
# 72.0 menor que 75

# %% [markdown]
# Exercício 7 – Desafio simples
# Crie um programa que:
# • Guarde o nome de um aluno
# • Guarde duas notas
# • Calcule a média
# • Mostre uma frase assim: O aluno João tirou média 7.5

# %%
aluno = input("digite o nome do aluno: ")
nota1 = float(input("digite a primeira nota: "))
nota2 = float(input("digite a segunda nota: "))
media = (nota1 + nota2) / 2
print(f"{aluno} ficou com a media de {media} ")
# Out:
# digite o nome do aluno: 2
# digite a primeira nota: 2
# digite a segunda nota: 2
# 2 ficou com a media de 2.0

# %% [markdown]
# Exercício 1 – Idade para dirigir
# Receba a idade de uma pessoa e diga se ela pode tirar carteira de motorista. A pessoa
# pode tirar a carteira se tiver idade maior ou igual a 18 anos.

# %%
idade = input("digite sua idade: ")
if idade >= "18":
  print("voce pode tirar a carteira")
else:
  print("voce nao pode tirar a carteira")

# %% [markdown]
# Exercício 2 – Par ou Ímpar
# Receba um número e diga se ele é par ou ímpar.

# %%
numero = input("digite um numero: ")
if numero % 2 == 0:
  print("o numero e par")
else:
  print("o numero e impar")

# %% [markdown]
# Exercício 3 – Maior de dois números
# Receba dois números e mostre qual é o maior. Se os dois números forem iguais, diga que
# eles são iguais.

# %%
numero1 = input("digite o primeiro numero: ")
numero2 = input("digite o segundo numero: ")
if numero1 > numero2:
  print("o primeiro numero e maior que o segundo")
elif numero1 < numero2:
  print("o segundo numero e maior que o primeiro")
elif numero1 == numero2:
  print("os dois numeros são iguais")
# Out:
# digite o primeiro numero: 1
# digite o segundo numero: 1
# os dois numeros são iguais

# %% [markdown]
# Exercício 4 – Situação do aluno
# Receba a nota de um aluno e mostre sua situação:
#  Nota maior ou igual a 7 → Aprovado
#  Nota maior ou igual a 5 e menor que 7 → Recuperação
#  Nota menor que 5 → Reprovad

# %%
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
n4 = float(input("Digite a quarta nota: "))

media = (n1 + n2 + n3 + n4) / 4

if media >= 7:
  print (f'foi aprovado com a media de {media}')
elif media >= 5 and media < 7:
  print(f"você ficou de recuperação com a media de {media}")
else:
  print(f'você foi reprovado com a media de {media}')

# %% [markdown]
# Exercício 5 – Desconto na compra
# Receba o valor de uma compra. Se o valor for maior ou igual a 100, aplique 10% de
# desconto e mostre o valor final. Caso contrário, mostre o valor normal da compra.

# %%
valor = float(input(" qual o valor da compra "))
if valor >= 100:
  desconto = valor / 10
  vf = valor - desconto
  print(f"valor final com desconto: {vf}")
else:
  print(f"valor da compra é {valor}")

# %% [markdown]
# Exercício 6 – Positivo, Negativo ou Zero
# Receba um número e diga se ele é positivo, negativo ou zero.

# %%
n = float(input("digite um numero "))
if n > 0:
  print(" o numero é positivo")
elif n < 0:
  print("o numero é negativo")
elif n == 0:
 print("zero")

# %% [markdown]
# Exercício 7 – Classificação de idade
# Receba a idade de uma pessoa e classifique-a de acordo com sua faixa etária:
#  Menor de 12 anos → Criança
#  De 12 a 17 anos → Adolescente
#  De 18 a 59 anos → Adulto
#  60 anos ou mais → Idoso

# %%
idade = int(input("qual sua idade? "))
if idade <= 12:
  print("criança")
elif idade <= 18 and idade >= 13:
  print("adolescente")
elif idade >= 19 and idade <= 59:
  print("adulto")
else:
  print("idoso")

# %% [markdown]
# xercício 8 – Média de duas notas
# Receba duas notas, calcule a média e diga se o aluno foi aprovado ou reprovado. O aluno
# será aprovado se a média for maior ou igual a 7.

# %%
nota1 = float(input("digite sua nota  "))
nota2 = float(input("digite sua nota  "))
notab = (nota1 + nota2) / 2
if notab >= 7:
  print(" aprovado")
else:
  print("reprovado")

# %% [markdown]
# Exercício 9 – Login simples
# Receba um usuário e uma senha. Se o usuário for "admin" e a senha for "1234", mostre
# "Login realizado com sucesso". Caso contrário, mostre "Usuário ou senha incorretos"

# %%
usuario = str(input("digite seu nome de usuario "))
senha = int(input("digite sua senha"))
print("cadastro realizado")
lusuario = str(input("digite seu nome de usuario "))
lsenha = int(input("digite sua senha"))
if usuario == lusuario and senha == lsenha:
  print("acesso permitido")
else:
  print(" acesso negado")

# %% [markdown]
# Exercício 10 – Calculadora de IMC
# Receba o peso e a altura de uma pessoa, calcule o IMC usando a fórmula:
# IMC = peso / (altura × altura)
# Depois, classifique o resultado:
#  IMC menor que 18.5 → Abaixo do peso
#  IMC de 18.5 a 24.9 → Peso normal
#  IMC de 25 a 29.9 → Sobrepeso
#  IMC maior ou igual a 30 → Obesidade

# %%
peso = float(input("qual seu peso? "))
altura = float(input("qual sua altura?"))
imc = peso / (altura * altura)
if imc < 18.5:
  print("abaixo do peso")
elif imc >= 18.5 and imc <= 24.9:
  print("peso normal")
elif imc >= 25 and imc <= 29.9:
  print("sobrepeso")
elif imc >= 30:
  print("obeso")
